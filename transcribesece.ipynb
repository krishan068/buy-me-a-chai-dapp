# %% [markdown]
# <a href="https://colab.research.google.com/github/krishan068/buy-me-a-chai-dapp/blob/main/transcribesece.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcome in google colab')
# Out:
# welcome in google colab
